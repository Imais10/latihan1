# %% [markdown]
# <a href="https://colab.research.google.com/github/Imais10/latihan1/blob/main/Latihan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "isma ayu fitriyani"
kelas = "xii tkj"
print("nama =",nama,"\n","kelas =",kelas)
# Out:
# nama = isma ayu fitriyani
#  kelas = xii tkj

# %%
pip install pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

dataset = '/content/sample_data/tweets.csv'
with open(dataset) as inisial_file:
  baca_file = csv.reader(inisial_file, delimiter=',')
  for baris in baca_file:
    print(baris)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# ['BarackObama', 'This is history: @OFA put more than 400k names on the permanent record of people who made health care reform happen. http://t.co/MddcLjKDvO', '', '21/08/2014 16:58', '5.025E+17', 'en', '', '', '604', '256']
# ['BarackObama', 'The economy should grow from the middle out, not the top down. Add your name if you agree: http://t.co/AKZaW19tgi #OpportunityForAll', '', '21/08/2014 15:03', '5.02471E+17', 'en', '', '', '1190', '622']
# ['BarackObama', "The economy is growing—but there's still more work to do. http://t.co/qDJ3WCC9KI #OpportunityForAll http://t.co/cRxqOGEnKq", '', '20/08/2014 22:06', '5.02215E+17', 'en', '', '', '1059', '614']
# ['BarackObama', 'ICYMI: American businesses have added 9.9 million jobs since early 2010. http://t.co/cjxvcyJ2ov #ActOnJobs', '', '20/08/2014 20:33', '5.02192E+17', 'en', '', '', '816', '400']
# ...
